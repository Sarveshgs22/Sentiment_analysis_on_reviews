# %%
import requests
from bs4 import BeautifulSoup

# %%
search_query="mobile+phones+all+price"

# %%
base_url="https://www.amazon.in/s?k="

# %%
url=base_url+search_query

# %%
url
# Out:
# 'https://www.amazon.in/s?k=mobile+phones+all+price'

# %%
header={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'}

# %%
search_response=requests.get(url,headers=header)

# %%
search_response.status_code
# Out:
# 200

# %%
search_response.text
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.
# ...

# %%
#to get the content of the page of required query
cookie={} # insert request cookies within{}
def getAmazonSearch(search_query):
    url="https://www.amazon.in/s?k="+search_query
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
#to get the contents of individual product pages using 'data-asin' no. (unique identification no.)
def Searchasin(asin):
    url="https://www.amazon.in/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
#to pass on the link of 'see all reviews' and extract the content
def Searchreviews(review_link):
    url="https://www.amazon.in"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
#getting all the product_names
product_names=[]
response=getAmazonSearch('mobile+phones+all+price')
soup=BeautifulSoup(response.content)
for i in soup.findAll("span",{'class':'a-size-medium a-color-base a-text-normal'}): # the tag which is common for all the names of products
    product_names.append(i.text) #adding the product names to the list
# Out:
# https://www.amazon.in/s?k=mobile+phones+all+price

# %%
product_names
# Out:
# ['Samsung Galaxy M21 (Raven Black, 6GB RAM, 128GB Storage)',
#  'OPPO A5 2020 (Dazzling White, 4GB RAM, 64GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage) – Dual Cameras & 5,000 mAH Battery',
#  'Redmi 8A Dual (Midnight Grey, 2GB RAM, 32GB Storage) – Dual Cameras & 5,000 mAH Battery',
#  'Samsung Galaxy M01 Core (Blue, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy M21 (Raven Black, 4GB RAM, 64GB Storage)',
#  'Panasonic Eluga i7 (2GB RAM, 16GB Storage, Finger Print Sensor, 4000mAh Battery) (Black)',
#  'Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)',
#  'Samsung Galaxy M01 Core (Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy A71 (Prism Crush Black, 8GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy A51 (Blue, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
# ...

# %%
len(product_names)
# Out:
# 22

# %%
#extracting data-asin numbers are similar to that of product names
data_asin=[]
response=getAmazonSearch('mobile+phones+all+price')
soup=BeautifulSoup(response.content)
for i in soup.findAll("div",{"sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-28-of-32 sg-col-16-of-20 sg-col sg-col-32-of-36 sg-col-12-of-16 sg-col-24-of-28"}):
    data_asin.append(i['data-asin'])
# Out:
# https://www.amazon.in/s?k=mobile+phones+all+price

# %%
data_asin
# Out:
# ['B07X4R63DF',
#  'B07SDPJ4XJ',
#  'B07HGGYWL6',
#  'B07X1KSLC3',
#  'B089MQ622N',
#  'B07HGH8D2R',
#  'B089MV96RW',
#  'B08BV2T63X',
#  'B07X1KSWZ3',
#  'B07HGJJ559',
#  'B07SBK1WQQ',
#  'B07HGH88GL',
#  'B07HGH8ML7',
#  'B07HGJ7WLM',
#  'B07KX1S161',
#  'B07SDPTP6Q']

# %%
len(data_asin)
# Out:
# 16

# %%
mobiles=['Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage) – Dual Cameras & 5,000 mAH Battery','OPPO A5 2020 (Dazzling White, 4GB RAM, 64GB Storage) with No Cost EMI/Additional Exchange Offers','Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB Storage)','Redmi 8A Dual (Midnight Grey, 2GB RAM, 32GB Storage) – Dual Cameras & 5,000 mAH Battery','Samsung Galaxy M01 Core (Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers','Samsung Galaxy M21 (Raven Black, 4GB RAM, 64GB Storage)','Samsung Galaxy M01 Core (Blue, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers','Panasonic Eluga i7 (2GB RAM, 16GB Storage, Finger Print Sensor, 4000mAh Battery) (Black)','Redmi 8A Dual (Sky White, 2GB RAM, 32GB Storage) – Dual Cameras & 5,000 mAH Battery','Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64GB Storage)','OPPO A5 2020 (Mirror Black, 3GB RAM, 64GB Storage) with No Cost EMI/Additional Exchange Offers','Samsung Galaxy M21 (Midnight Blue, 6GB RAM, 128GB Storage)','Samsung Galaxy M21 (Raven Black, 6GB RAM, 128GB Storage)','Samsung Galaxy M31 (Space Black, 6GB RAM, 64GB Storage)','Vivo Y91i (Fusion Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers','OPPO A5 2020 (Dazzling White, 3GB RAM, 64GB Storage) with No Cost EMI/Additional Exchange Offers']

# %%
#extracting "see all reviews" links using data_asin
link=[]
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.in/dp/B07X4R63DF
# https://www.amazon.in/dp/B07SDPJ4XJ
# https://www.amazon.in/dp/B07HGGYWL6
# https://www.amazon.in/dp/B07X1KSLC3
# https://www.amazon.in/dp/B089MQ622N
# https://www.amazon.in/dp/B07HGH8D2R
# https://www.amazon.in/dp/B089MV96RW
# https://www.amazon.in/dp/B08BV2T63X
# https://www.amazon.in/dp/B07X1KSWZ3
# https://www.amazon.in/dp/B07HGJJ559
# https://www.amazon.in/dp/B07SBK1WQQ
# https://www.amazon.in/dp/B07HGH88GL
# https://www.amazon.in/dp/B07HGH8ML7
# https://www.amazon.in/dp/B07HGJ7WLM
# https://www.amazon.in/dp/B07KX1S161
# https://www.amazon.in/dp/B07SDPTP6Q

# %%
#extracting the reviews in any number of pages
reviews=[]
mobile_phones=[]
for j in range(len(link)):
    for k in range(100):#100 pages of review
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            mobile_phones.append(product_names[j])
            reviews.append(i.text)
# Out:
# https://www.amazon.in/Redmi-8A-Dual-Blue-Storage/product-reviews/B07X4R63DF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Redmi-8A-Dual-Blue-Storage/product-reviews/B07X4R63DF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Redmi-8A-Dual-Blue-Storage/product-reviews/B07X4R63DF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Redmi-8A-Dual-Blue-Storage/product-reviews/B07X4R63DF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Redmi-8A-Dual-Blue-Storage/product-reviews/B07X4R63DF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Redmi-8A-Dual-Blue-Storage/product-reviews/B07X4R63DF/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# ...

# %%
search_query_1 = "mobile+phones+oneplus"#for extracting more mobile phone reviews

# %%
url_1 = base_url+search_query_1

# %%
search_response_1=requests.get(url_1,headers=header)

# %%
search_response_1.status_code
# Out:
# 200

# %%
search_response_1.text
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->\n<!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->\n<!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!-->\n<html class="a-no-js" lang="en-us"><!--<![endif]--><head>\n<meta http-equiv="content-type" content="text/html; charset=UTF-8">\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n<title dir="ltr">Amazon.in</title>\n<meta name="viewport" content="width=device-width">\n<link rel="stylesheet" href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css">\n<script>\n\nif (true === true) {\n    var ue_t0 = (+ new Date()),\n        ue_csm = window,\n        ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },\n        ue_furl = "fls-eu.amazon.in",\n        ue_mid = "
# ...

# %%
product_names_1=[]
response_1=getAmazonSearch('mobile+phones+oneplus')
soup_1=BeautifulSoup(response_1.content)
for i in soup_1.findAll("span",{'class':'a-size-medium a-color-base a-text-normal'}): # the tag which is common for all the names of products
    product_names_1.append(i.text) #adding the product names to the list
# Out:
# https://www.amazon.in/s?k=mobile+phones+oneplus

# %%
product_names_1
# Out:
# ['OnePlus Nord 5G (Gray Onyx, 8GB RAM, 128GB Storage)',
#  'OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB Storage)',
#  'OnePlus 8 (Onyx Black 12GB RAM+256GB Storage)',
#  'OnePlus 8 (Glacial Green 6GB RAM+128GB Storage)',
#  'OnePlus 7T (Glacier Blue, 8GB RAM, Fluid AMOLED Display, 256GB Storage, 3800mAH Battery)',
#  'OnePlus Nord 5G (Gray Ash, 12GB RAM, 256GB Storage)',
#  'OnePlus Nord 5G (Gray Onyx, 6GB RAM, 64GB Storage)',
#  'OnePlus 3T (Gunmetal)',
#  'OnePlus 8 Pro (Onyx Black 12GB RAM+256GB Storage)',
#  'OnePlus 8 (Onyx Black 8GB RAM+128GB Storage)',
#  'OnePlus 8 Pro (Glacial Green 12GB RAM+256GB Storage)',
#  'OnePlus 8T 5G (Lunar Silver, 8GB RAM, 128GB Storage)',
#  'OnePlus 8 Pro (Onyx Black 8GB RAM+128GB Storage)',
#  'OnePlus 8T 5G (Aquamarine Green, 12GB RAM, 256GB Storage)',
#  'OnePlus 8T 5G (Aquamarine Green, 8GB RAM, 128GB Storage)',
#  '(Renewed) OnePlus Nord 5G (Gray Onyx, 8GB RAM, 128GB Storage)']

# %%
len(product_names_1)
# Out:
# 16

# %%
#extracting data-asin numbers are similar to that of product names
data_asin_1=[]
response_1=getAmazonSearch('mobile+phones+oneplus')
soup_1=BeautifulSoup(response_1.content)
for i in soup_1.findAll("div",{"sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-28-of-32 sg-col-16-of-20 sg-col sg-col-32-of-36 sg-col-12-of-16 sg-col-24-of-28"}):
    data_asin_1.append(i['data-asin'])
# Out:
# https://www.amazon.in/s?k=mobile+phones+oneplus

# %%
data_asin_1
# Out:
# ['B08695ZSP6',
#  'B086977J3K',
#  'B078BNQ318',
#  'B0756ZFXWP',
#  'B07DJLVJ5M',
#  'B085J1PFYB',
#  'B08697MJD8',
#  'B071Z97T2C',
#  'B077PWK5BY',
#  'B01FM8M0XE',
#  'B07DJCYBVK',
#  'B078BN55WZ',
#  'B085J1JDB7',
#  'B085J17VVP',
#  'B085J19V4P',
#  'B08L39DNQQ']

# %%
len(data_asin_1)
# Out:
# 16

# %%
#extracting "see all reviews" links using data_asin
link_1=[]
for i in range(len(data_asin_1)):
    response_1=Searchasin(data_asin_1[i])
    soup_1=BeautifulSoup(response_1.content)
    for i in soup_1.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link_1.append(i['href'])
# Out:
# https://www.amazon.in/dp/B08695ZSP6
# https://www.amazon.in/dp/B086977J3K
# https://www.amazon.in/dp/B078BNQ318
# https://www.amazon.in/dp/B0756ZFXWP
# https://www.amazon.in/dp/B07DJLVJ5M
# https://www.amazon.in/dp/B085J1PFYB
# https://www.amazon.in/dp/B08697MJD8
# https://www.amazon.in/dp/B071Z97T2C
# https://www.amazon.in/dp/B077PWK5BY
# https://www.amazon.in/dp/B01FM8M0XE
# https://www.amazon.in/dp/B07DJCYBVK
# https://www.amazon.in/dp/B078BN55WZ
# https://www.amazon.in/dp/B085J1JDB7
# https://www.amazon.in/dp/B085J17VVP
# https://www.amazon.in/dp/B085J19V4P
# https://www.amazon.in/dp/B08L39DNQQ

# %%
mobiles_1=['OnePlus Nord 5G (Gray Onyx, 8GB RAM, 128GB Storage)','OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB Storage)','OnePlus 8 (Glacial Green 6GB RAM+128GB Storage)','OnePlus 8 (Onyx Black 12GB RAM+256GB Storage)','OnePlus 7T (Glacier Blue, 8GB RAM, Fluid AMOLED Display, 256GB Storage, 3800mAH Battery)','OnePlus 8T 5G (Lunar Silver, 8GB RAM, 128GB Storage)','OnePlus Nord 5G (Gray Ash, 12GB RAM, 256GB Storage)','OnePlus 8 (Onyx Black 8GB RAM+128GB Storage)','OnePlus 8 Pro (Glacial Green 12GB RAM+256GB Storage)','OnePlus 3T (Gunmetal)','OnePlus 8 Pro (Onyx Black 8GB RAM+128GB Storage)','OnePlus 8 Pro (Onyx Black 12GB RAM+256GB Storage)','OnePlus Nord 5G (Gray Onyx, 6GB RAM, 64GB Storage)','OnePlus 8T 5G (Aquamarine Green, 8GB RAM, 128GB Storage)','OnePlus 8T 5G (Aquamarine Green, 12GB RAM, 256GB Storage)','(Renewed) OnePlus Nord 5G (Blue Marble, 8GB RAM, 128GB Storage)']

# %%
for j in range(len(link_1)):
    for k in range(100):#100 pages of review
        response_1=Searchreviews(link_1[j]+'&pageNumber='+str(k))
        soup_1=BeautifulSoup(response_1.content)
        for i in soup_1.findAll("span",{'data-hook':"review-body"}):
            mobile_phones.append(product_names_1[j])
            reviews.append(i.text)
# Out:
# https://www.amazon.in/Test-Exclusive-748/product-reviews/B07DJLVJ5M?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Test-Exclusive-748/product-reviews/B07DJLVJ5M?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Test-Exclusive-748/product-reviews/B07DJLVJ5M?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Test-Exclusive-748/product-reviews/B07DJLVJ5M?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Test-Exclusive-748/product-reviews/B07DJLVJ5M?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Test-Exclusive-748/product-reviews/B07DJLVJ5M?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Test-Exclusive-748/product-reviews/B07DJLVJ5M?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Test-Exclusive-748/product-reviews/B07DJLVJ5M?reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Test-Exclusive-748/product-reviews/B07DJLVJ5M?reviewerType=all_reviews&pageNumber=8
# ...

# %%
search_query_2 = "mobile+phones+nokia"

# %%
url_2 = base_url+search_query_2

# %%
search_response_2=requests.get(url_2,headers=header)

# %%
search_response_2.status_code
# Out:
# 200

# %%
search_response_2.text
# Out:
# '<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function(){return+new Date};e.d=function(b){return f()-(b?0:d.ue_t0)};e.stub=function(b,a){if(!b[a]){var c=[];b[a]=function(){c.push([c.slice.call(arguments),e.d(),d.ue_id])};b[a].replay=function(b){for(var a;a=c.
# ...

# %%
product_names_2=[]
response_2=getAmazonSearch('mobile+phones+nokia')
soup_2=BeautifulSoup(response_2.content)
for i in soup_2.findAll("span",{'class':'a-size-medium a-color-base a-text-normal'}): # the tag which is common for all the names of products
    product_names_2.append(i.text) #adding the product names to the list
# Out:
# https://www.amazon.in/s?k=mobile+phones+nokia

# %%
product_names_2
# Out:
# ['Nokia 105 2019 (Single SIM, Black)',
#  'NOKIA 105 New 2019 (Dual SIM, Black)',
#  'Nokia 150 (Dual SIM, Black)',
#  'Nokia 216 (Black)',
#  'Nokia 105 2019 (Single SIM, Blue)',
#  'Nokia 216 (Grey)',
#  'Nokia 110 Dual SIM (Black)',
#  'Nokia 105 2019 (Single SIM, Pink)',
#  '(Renewed) Nokia 215 (Dual SIM, Black)',
#  'Nokia 150 (Dual SIM, White)',
#  'Nokia 5.3 Android One Smartphone with Quad Camera, 6 GB RAM and 64 GB Storage - Cyan',
#  'Nokia 105 (Black)',
#  'Nokia 5.3 Android One Smartphone with Quad Camera, 4 GB RAM and 64 GB Storage - Charcoal',
#  'Nokia 150 (2020) (Red)',
#  'Nokia 5310 Dual SIM Feature Phone with MP3 Player, Wireless FM Radio and Rear Camera',
#  '(Renewed) Nokia 215 (Dual SIM, White)']

# %%
len(product_names_2)
# Out:
# 16

# %%
#extracting data-asin numbers are similar to that of product names
data_asin_2=[]
response_2=getAmazonSearch('mobile+phones+nokia')
soup_2=BeautifulSoup(response_2.content)
for i in soup_2.findAll("div",{"sg-col-20-of-24 s-result-item s-asin sg-col-0-of-12 sg-col-28-of-32 sg-col-16-of-20 sg-col sg-col-32-of-36 sg-col-12-of-16 sg-col-24-of-28"}):
    data_asin_2.append(i['data-asin'])
# Out:
# https://www.amazon.in/s?k=mobile+phones+nokia

# %%
data_asin_2
# Out:
# ['B07YYNX5X6',
#  'B07WXW8V4X',
#  'B06XQYCG4B',
#  'B01M69DXTB',
#  'B07YYNLCD2',
#  'B07ZG5DQHV',
#  'B01MG69BWT',
#  'B07YYMYXVD',
#  'B08354WLSB',
#  'B06XQHBLD9',
#  'B0745BNFYV',
#  'B08GT1DVC4',
#  'B08GT299NQ',
#  'B08H1Z5Y9Z',
#  'B08BG6FQ2S',
#  'B08354RKY5']

# %%
len(data_asin_2)
# Out:
# 16

# %%
#extracting "see all reviews" links using data_asin
link_2=[]
for i in range(len(data_asin_2)):
    response_2=Searchasin(data_asin_2[i])
    soup_2=BeautifulSoup(response_2.content)
    for i in soup_2.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link_2.append(i['href'])
# Out:
# https://www.amazon.in/dp/B07YYNX5X6
# https://www.amazon.in/dp/B07WXW8V4X
# https://www.amazon.in/dp/B06XQYCG4B
# https://www.amazon.in/dp/B01M69DXTB
# https://www.amazon.in/dp/B07YYNLCD2
# https://www.amazon.in/dp/B07ZG5DQHV
# https://www.amazon.in/dp/B01MG69BWT
# https://www.amazon.in/dp/B07YYMYXVD
# https://www.amazon.in/dp/B08354WLSB
# https://www.amazon.in/dp/B06XQHBLD9
# https://www.amazon.in/dp/B0745BNFYV
# https://www.amazon.in/dp/B08GT1DVC4
# https://www.amazon.in/dp/B08GT299NQ
# https://www.amazon.in/dp/B08H1Z5Y9Z
# https://www.amazon.in/dp/B08BG6FQ2S
# https://www.amazon.in/dp/B08354RKY5

# %%
mobiles_2 = ['Nokia 105 2019 (Single SIM, Black)',
 'NOKIA 105 New 2019 (Dual SIM, Black)',
 'Nokia 150 (Dual SIM, Black)',
 'Nokia 216 (Black)',
 'Nokia 105 2019 (Single SIM, Blue)',
 'Nokia 110 Dual SIM (Black)',
 'Nokia 216 (Grey)',
 'Nokia 105 2019 (Single SIM, Pink)',
 '(Renewed) Nokia 215 (Dual SIM, Black)',
 'Nokia 150 (Dual SIM, White)',
 'Nokia 105 (Black)',
 'Nokia 5.3 Android One Smartphone with Quad Camera, 6 GB RAM and 64 GB Storage - Cyan',
 'Nokia 5.3 Android One Smartphone with Quad Camera, 4 GB RAM and 64 GB Storage - Charcoal',
 'Nokia 150 (2020) (Red)',
 'Nokia 5310 Dual SIM Feature Phone with MP3 Player, Wireless FM Radio and Rear Camera',
 '(Renewed) Nokia 215 (Dual SIM, White)']

# %%
for j in range(len(link_2)):
    for k in range(100):#100 pages of review
        response_2=Searchreviews(link_2[j]+'&pageNumber='+str(k))
        soup_2=BeautifulSoup(response_2.content)
        for i in soup_2.findAll("span",{'data-hook':"review-body"}):
            mobile_phones.append(product_names_2[j])
            reviews.append(i.text)
# Out:
# https://www.amazon.in/Nokia-150-Dual-SIM-Black/product-reviews/B06XQYCG4B?reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Nokia-150-Dual-SIM-Black/product-reviews/B06XQYCG4B?reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Nokia-150-Dual-SIM-Black/product-reviews/B06XQYCG4B?reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Nokia-150-Dual-SIM-Black/product-reviews/B06XQYCG4B?reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Nokia-150-Dual-SIM-Black/product-reviews/B06XQYCG4B?reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Nokia-150-Dual-SIM-Black/product-reviews/B06XQYCG4B?reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Nokia-150-Dual-SIM-Black/product-reviews/B06XQYCG4B?reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Nokia-150-Dual-SIM-Black/product-reviews/B06XQYCG4B?reviewerType=all_reviews&pageNumber=7
# ...

# %%
len(reviews)
# Out:
# 23417

# %%
import pandas as pd

# %%
 #converting the reviews list and mobile_phones list into a dictionary
rev_mob = {'reviews':reviews,'mobile':mobile_phones}

# %%
review_data=pd.DataFrame(rev_mob) #converting this dictionary into a dataframe

# %%
review_data.head()
# Out:
#                                              reviews  \
# 0  \n\n   Defective product shipped.. reported wi...
# 1  \n\n  Nice phone camera better attractive look...
# 2  \n\n  Design-GoodCamera-NiceDisplay-satisfacto...
# 3  \n\n  The headphone jack is not working  😡 Des...
# 4  \n\n  First sell, First order. Mobile is very ...
#
#                                               mobile
# 0  Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage...
# 1  Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage...
# 2  Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage...
# 3  Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage...
# 4  Redmi 8A Dual (Sea Blue, 2GB RAM, 32GB Storage...

# %%
review_data.shape
# Out:
# (23417, 2)

# %%
review_data.to_csv('Scraping reviews_1_new.csv',index=False) #converting the dataframe to a csv file

# %%
len(mobile_phones)
# Out:
# 23417

# %%
len(mobiles)
# Out:
# 16

# %%
len(mobiles_1)
# Out:
# 16

# %%
len(mobiles_2)
# Out:
# 16
